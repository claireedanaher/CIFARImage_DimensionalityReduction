# %% [markdown]
# ## On CIFAR10 Gray Data
#
# #### Autoencoders
# #### Kirty Vedula

# %%
from IPython.display import Image, SVG
# %matplotlib inline

import numpy as np
import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
from keras import regularizers
from keras.utils import np_utils
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.utils import check_random_state
from sklearn.decomposition import PCA
from sklearn.manifold import SpectralEmbedding
from sklearn.manifold import Isomap
from sklearn import svm
# Out:
# C:\Users\kpvedula\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def deep_autoencoder_CIFAR(x_train, x_test, encoding_dim, ec_dim_1, ec_dim_2):
    # input dimension = 1024
    input_dim = x_train.shape[1]
    
    compression_factor = float(input_dim) / encoding_dim
    print("Compression factor: %s" % compression_factor)
    
    autoencoder = Sequential()

    # Encoder Layers
    autoencoder.add(Dense(4 * encoding_dim, input_shape=(input_dim,), activation='relu'))
    autoencoder.add(Dense(2 * encoding_dim, activation='relu'))
    autoencoder.add(Dense(encoding_dim, activation='relu'))

    # Decoder Layers
    autoencoder.add(Dense(2 * encoding_dim, activation='relu'))
    autoencoder.add(Dense(4 * encoding_dim, activation='relu'))
    autoencoder.add(Dense(input_dim, activation='sigmoid'))

    autoencoder.summary()

    input_img = Input(shape=(input_dim,))
    encoder_layer1 = autoencoder.layers[0]
    encoder_layer2 = autoencoder.layers[1]
    encoder_layer3 = autoencoder.layers[2]
    encoder = Model(input_img, encoder_layer3(encoder_layer2(encoder_layer1(input_img))))

    encoder.summary()
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    autoencoder.fit(x_train, x_train,
                    epochs=50,
                    batch_size=256,
                    validation_data=(x_test, x_test))
    return encoder, autoencoder

# %%
def conv_autoencoder_CIFAR(x_train, x_test, encoding_dim, ec_dim_1, ec_dim_2):

    x_train = x_train.reshape((len(x_train), 32, 32, 1))
    x_test = x_test.reshape((len(x_test), 32, 32, 1))

    autoencoder = Sequential()

    # Encoder Layers
    autoencoder.add(Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=x_train.shape[1:]))
    autoencoder.add(MaxPooling2D((2, 2), padding='same'))
    autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
    autoencoder.add(MaxPooling2D((2, 2), padding='same'))
    autoencoder.add(Conv2D(8, (3, 3), strides=(2,2), activation='relu', padding='same'))

    # Flatten encoding for visualization
    autoencoder.add(Flatten())
    autoencoder.add(Reshape((4, 4, 8)))

    # Decoder Layers
    autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
    autoencoder.add(UpSampling2D((2, 2)))
    autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
    autoencoder.add(UpSampling2D((2, 2)))
    autoencoder.add(Conv2D(16, (3, 3), activation='relu'))
    autoencoder.add(UpSampling2D((2, 2)))
    autoencoder.add(Conv2D(1, (3, 3), activation='sigmoid', padding='same'))

    autoencoder.summary()


    encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('flatten_1').output)
    encoder.summary()


    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    autoencoder.fit(x_train, x_train,
                    epochs=70,
                    batch_size=128,
                    validation_data=(x_test, x_test))
    return encoder, autoencoder

# %%
def simple_autoencoder_CIFAR(x_train, x_test, encoding_dim, ec_dim_1, ec_dim_2):
    # input dimension = 1024
    input_dim = x_train.shape[1]
    
    compression_factor = float(input_dim) / encoding_dim
    print("Compression factor: %s" % compression_factor)
    
    autoencoder = Sequential()
    autoencoder.add(
        Dense(encoding_dim, input_shape=(input_dim,), activation='relu')
    )
    autoencoder.add(
        Dense(input_dim, activation='sigmoid')
    )

    autoencoder.summary()
    input_img = Input(shape=(input_dim,))
    encoder_layer = autoencoder.layers[0]
    encoder = Model(input_img, encoder_layer(input_img))

    encoder.summary()
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    autoencoder.fit(x_train, x_train,
                    epochs=50,
                    batch_size=256,
                    shuffle=True,
                    validation_data=(x_test, x_test))
    return encoder, autoencoder

# %%
def plot_figs(x_test, y_test, encoded_imgs, decoded_imgs, ec_dim_1, ec_dim_2, labels):
    y_test = np.squeeze(y_test)
    num_images = 10
    np.random.seed(42)
    random_test_images = np.random.randint(x_test.shape[0], size=num_images)
#     print(enumerate(random_test_images))
    plt.figure(figsize=(18, 4))
#     labels = np.append(y_test[image_idx in enumerate(random_test_images)])
    
    for i, image_idx in enumerate(random_test_images):
        # plot original image
        ax = plt.subplot(3, num_images, i + 1)
        plt.imshow(x_test[image_idx].reshape(32, 32,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # plot encoded image
        ax = plt.subplot(3, num_images, num_images + i + 1)
        plt.imshow(encoded_imgs[image_idx].reshape(ec_dim_1, ec_dim_2,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # plot reconstructed image
        ax = plt.subplot(3, num_images, 2*num_images + i + 1)
        plt.imshow(decoded_imgs[image_idx].reshape(32, 32,3))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        
    plt.show()
    
    encoded_df = pd.DataFrame(encoded_imgs)
    
#     n = encoded_df.shape[0]
#     r = 2 * np.random.rand(n)
#     theta = 2 * np.pi * np.random.rand(n)
#     area = 200 * r**2 * np.random.rand(n)
    colors = ['b','r']
    c = plt.scatter(encoded_df[0], encoded_df[1], c=colors)
    plt.show()

# %%
# def convert_grayscale_to_fourier(data, dtype='float32'):
#     fourier_images = np.zeros([data.shape[0],data.shape[1],data.shape[2]])
#     for i in range(data.shape[0]):
#         data[i,:,:] = np.squeeze(data[i,:,:])
#         fourier_images[i,:,:] = np.fft.fft2(data[i,:,:])
#         fourier_images[i,:,:] = np.fft.fftshift(fourier_images[i,:])
#         fourier_images[i,:,:] = np.angle(fourier_images[i,:,:])
#     return fourier_images

# %%
# def grayscale(data, dtype='float32'):
#     # luma coding weighted average in video systems
#     r, g, b = np.asarray(.21, dtype=dtype), np.asarray(.72, dtype=dtype), np.asarray(.07, dtype=dtype)
#     rst = r * data[:, :, :, 0] + g * data[:, :, :, 1] + b * data[:, :, :, 2]
#     # add channel dimension
# #     rst = np.expand_dims(rst, axis=3)
#     return rst

# %%
# Loads the training and test data sets (ignoring class labels)
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
num_images = 10
np.random.seed(42)
test_indices = []

nb_classes = 10
class_names = { 0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck',}

random_test_images = np.random.randint(x_test.shape[0], size=num_images)
for index, value in enumerate(random_test_images):
    test_indices.append(value)
test_labels = y_test[test_indices]

# %%
# x_gray_train = grayscale(x_train)
# x_gray_test = grayscale(x_test)
# x_gray_train = np.expand_dims(x_gray_train, axis=3)
# x_gray_test = np.expand_dims(x_gray_test, axis=3)

# x_train = x_gray_train
# x_test = x_gray_test

# %%
# x_fourier_train = convert_grayscale_to_fourier(grayscale(x_train))
# x_fourier_test = convert_grayscale_to_fourier(grayscale(x_test))

# x_train = x_fourier_train
# x_test = x_fourier_test

# %%
# now we have only one channel in the images
img_channels = 1

# Scales the training and test data to range between 0 and 1.
max_value = float(x_train.max())
x_train = x_train.astype('float32') / max_value
x_test = x_test.astype('float32') / max_value

# Reshape the 3D arrays as matrices. In doing so, we'll reshape the 28 x 28 images into vectors of length 784

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

(x_train.shape, x_test.shape)
# Out:
# ((50000, 3072), (10000, 3072))

# %%
encoding_dim = 64*3
ec_dim_1 = 8
ec_dim_2 = 8

# %%
simple_encoder, simple_autoencoder = simple_autoencoder_CIFAR(x_train, x_test, encoding_dim, ec_dim_1, ec_dim_2)
# Out:
# Compression factor: 16.0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 192)               590016
# _________________________________________________________________
# dense_2 (Dense)              (None, 3072)              592896
# =================================================================
# Total params: 1,182,912
# Trainable params: 1,182,912
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 192)               590016
# =================================================================
# Total params: 590,016
# Trainable params: 590,016
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.6362 - val_loss: 0.6170
# Epoch 2/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.6095 - val_loss: 0.6049
# Epoch 3/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.6004 - val_loss: 0.5982
# Epoch 4/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5945 - val_loss: 0.5943
# Epoch 5/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5907 - val_loss: 0.5890
# Epoch 6/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5873 - val_loss: 0.5863
# Epoch 7/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5851 - val_loss: 0.5844
# Epoch 8/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5834 - val_loss: 0.5829
# Epoch 9/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5820 - val_loss: 0.5834
# Epoch 10/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5815 - val_loss: 0.5817
# Epoch 11/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5809 - val_loss: 0.5827
# Epoch 12/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.5807 - val_loss: 0.5815
# Epoch 13/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5799 - val_loss: 0.5809
# Epoch 14/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5799 - val_loss: 0.5811
# Epoch 15/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5800 - val_loss: 0.5801
# Epoch 16/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5798 - val_loss: 0.5803
# Epoch 17/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5796 - val_loss: 0.5800
# Epoch 18/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5794 - val_loss: 0.5801
# Epoch 19/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5796 - val_loss: 0.5800
# Epoch 20/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5792 - val_loss: 0.5801
# Epoch 21/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5796 - val_loss: 0.5799
# Epoch 22/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5792 - val_loss: 0.5809
# Epoch 23/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5793 - val_loss: 0.5797
# Epoch 24/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5791 - val_loss: 0.5808
# Epoch 25/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5791 - val_loss: 0.5799
# Epoch 26/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5794 - val_loss: 0.5803
# Epoch 27/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5790 - val_loss: 0.5810
# Epoch 28/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5794 - val_loss: 0.5799
# Epoch 29/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 30/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5792 - val_loss: 0.5810
# Epoch 31/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5789 - val_loss: 0.5803
# Epoch 32/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5791 - val_loss: 0.5796
# Epoch 33/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5790 - val_loss: 0.5806
# Epoch 34/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5794 - val_loss: 0.5796
# Epoch 35/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5788 - val_loss: 0.5803
# Epoch 36/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 37/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5790 - val_loss: 0.5796
# Epoch 38/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5790 - val_loss: 0.5799
# Epoch 39/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 40/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5792 - val_loss: 0.5795
# Epoch 41/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5788 - val_loss: 0.5803
# Epoch 42/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5789 - val_loss: 0.5804
# Epoch 43/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5790 - val_loss: 0.5802
# Epoch 44/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 45/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5789 - val_loss: 0.5801
# Epoch 46/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 47/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5789 - val_loss: 0.5795
# Epoch 48/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5787 - val_loss: 0.5796
# Epoch 49/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5795
# Epoch 50/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5788 - val_loss: 0.5796

# %%
simple_encoded_imgs = simple_encoder.predict(x_test)
simple_decoded_imgs = simple_autoencoder.predict(x_test)

# %%
plot_figs(x_test, y_test, simple_encoded_imgs, simple_decoded_imgs,ec_dim_1, ec_dim_2, test_labels)

# %%
deep_encoder, deep_autoencoder = deep_autoencoder_CIFAR(x_train, x_test, encoding_dim, ec_dim_1, ec_dim_2)
# Out:
# Compression factor: 16.0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 768)               2360064
# _________________________________________________________________
# dense_4 (Dense)              (None, 384)               295296
# _________________________________________________________________
# dense_5 (Dense)              (None, 192)               73920
# _________________________________________________________________
# dense_6 (Dense)              (None, 384)               74112
# _________________________________________________________________
# dense_7 (Dense)              (None, 768)               295680
# _________________________________________________________________
# dense_8 (Dense)              (None, 3072)              2362368
# =================================================================
# Total params: 5,461,440
# Trainable params: 5,461,440
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 768)               2360064
# _________________________________________________________________
# dense_4 (Dense)              (None, 384)               295296
# _________________________________________________________________
# dense_5 (Dense)              (None, 192)               73920
# =================================================================
# Total params: 2,729,280
# Trainable params: 2,729,280
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.6357 - val_loss: 0.6142
# Epoch 2/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.6022 - val_loss: 0.6002
# Epoch 3/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5956 - val_loss: 0.5934
# Epoch 4/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5906 - val_loss: 0.5907
# Epoch 5/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5881 - val_loss: 0.5872
# Epoch 6/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5859 - val_loss: 0.5850
# Epoch 7/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5839 - val_loss: 0.5836
# Epoch 8/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5825 - val_loss: 0.5823
# Epoch 9/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5813 - val_loss: 0.5815
# Epoch 10/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5802 - val_loss: 0.5808
# Epoch 11/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.5794 - val_loss: 0.5802
# Epoch 12/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5784 - val_loss: 0.5785
# Epoch 13/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5777 - val_loss: 0.5791
# Epoch 14/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5776 - val_loss: 0.5791
# Epoch 15/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5767 - val_loss: 0.5775
# Epoch 16/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5762 - val_loss: 0.5771
# Epoch 17/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5757 - val_loss: 0.5765
# Epoch 18/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5751 - val_loss: 0.5802
# Epoch 19/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5752 - val_loss: 0.5755
# Epoch 20/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5745 - val_loss: 0.5749
# Epoch 21/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5740 - val_loss: 0.5745
# Epoch 22/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5738 - val_loss: 0.5747
# Epoch 23/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5736 - val_loss: 0.5742
# Epoch 24/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5734 - val_loss: 0.5742
# Epoch 25/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5731 - val_loss: 0.5734
# Epoch 26/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5728 - val_loss: 0.5763
# Epoch 27/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5726 - val_loss: 0.5730
# Epoch 28/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5723 - val_loss: 0.5731
# Epoch 29/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5721 - val_loss: 0.5757
# Epoch 30/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5719 - val_loss: 0.5730
# Epoch 31/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.5715 - val_loss: 0.5721
# Epoch 32/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5715 - val_loss: 0.5723
# Epoch 33/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5712 - val_loss: 0.5729
# Epoch 34/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5708 - val_loss: 0.5718
# Epoch 35/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5709 - val_loss: 0.5754
# Epoch 36/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5708 - val_loss: 0.5727
# Epoch 37/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5705 - val_loss: 0.5713
# Epoch 38/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.5704 - val_loss: 0.5719
# Epoch 39/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5701 - val_loss: 0.5711
# Epoch 40/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5700 - val_loss: 0.5717
# Epoch 41/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5701 - val_loss: 0.5723
# Epoch 42/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5699 - val_loss: 0.5708
# Epoch 43/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5695 - val_loss: 0.5727
# Epoch 44/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5695 - val_loss: 0.5706
# Epoch 45/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5697 - val_loss: 0.5703
# Epoch 46/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5692 - val_loss: 0.5704
# Epoch 47/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5693 - val_loss: 0.5712
# Epoch 48/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5690 - val_loss: 0.5729
# Epoch 49/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5692 - val_loss: 0.5707
# Epoch 50/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.5688 - val_loss: 0.5698

# %%
deep_encoded_imgs = deep_encoder.predict(x_test)
deep_decoded_imgs = deep_autoencoder.predict(x_test)

# %%
plot_figs(x_test,y_test, deep_encoded_imgs, deep_decoded_imgs, ec_dim_1, ec_dim_2, test_labels)

# %%
conv_encoder, conv_autoencoder = simple_autoencoder_CIFAR(x_train, x_test, encoding_dim, ec_dim_1, ec_dim_2)
# Out:
# Compression factor: 16.0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 192)               590016
# _________________________________________________________________
# dense_10 (Dense)             (None, 3072)              592896
# =================================================================
# Total params: 1,182,912
# Trainable params: 1,182,912
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 192)               590016
# =================================================================
# Total params: 590,016
# Trainable params: 590,016
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.6362 - val_loss: 0.6170
# Epoch 2/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.6095 - val_loss: 0.6049
# Epoch 3/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.6004 - val_loss: 0.5982
# Epoch 4/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5945 - val_loss: 0.5943
# Epoch 5/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5907 - val_loss: 0.5890
# Epoch 6/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5873 - val_loss: 0.5863
# Epoch 7/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5851 - val_loss: 0.5844
# Epoch 8/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5834 - val_loss: 0.5829
# Epoch 9/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5820 - val_loss: 0.5834
# Epoch 10/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5815 - val_loss: 0.5817
# Epoch 11/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5809 - val_loss: 0.5827
# Epoch 12/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5807 - val_loss: 0.5815
# Epoch 13/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5799 - val_loss: 0.5809
# Epoch 14/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5799 - val_loss: 0.5811
# Epoch 15/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5800 - val_loss: 0.5801
# Epoch 16/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5798 - val_loss: 0.5803
# Epoch 17/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5796 - val_loss: 0.5800
# Epoch 18/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5794 - val_loss: 0.5801
# Epoch 19/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5796 - val_loss: 0.5800
# Epoch 20/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5792 - val_loss: 0.5801
# Epoch 21/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5796 - val_loss: 0.5799
# Epoch 22/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5792 - val_loss: 0.5809
# Epoch 23/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5793 - val_loss: 0.5797
# Epoch 24/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5791 - val_loss: 0.5808
# Epoch 25/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5791 - val_loss: 0.5799
# Epoch 26/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5794 - val_loss: 0.5803
# Epoch 27/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5790 - val_loss: 0.5810
# Epoch 28/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5794 - val_loss: 0.5799
# Epoch 29/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 30/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5792 - val_loss: 0.5810
# Epoch 31/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5789 - val_loss: 0.5803
# Epoch 32/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5791 - val_loss: 0.5796
# Epoch 33/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5790 - val_loss: 0.5806
# Epoch 34/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5794 - val_loss: 0.5796
# Epoch 35/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5788 - val_loss: 0.5803
# Epoch 36/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 37/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5790 - val_loss: 0.5796
# Epoch 38/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.5790 - val_loss: 0.5799
# Epoch 39/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 40/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.5792 - val_loss: 0.5795
# Epoch 41/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5788 - val_loss: 0.5803
# Epoch 42/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5804
# Epoch 43/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5790 - val_loss: 0.5802
# Epoch 44/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 45/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5789 - val_loss: 0.5801
# Epoch 46/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5789 - val_loss: 0.5796
# Epoch 47/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5789 - val_loss: 0.5795
# Epoch 48/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.5787 - val_loss: 0.5796
# Epoch 49/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5789 - val_loss: 0.5795
# Epoch 50/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5788 - val_loss: 0.5796

# %%
conv_encoded_imgs = conv_encoder.predict(x_test)
conv_decoded_imgs = conv_autoencoder.predict(x_test)

# %%
plot_figs(x_test,y_test, conv_encoded_imgs, conv_decoded_imgs, ec_dim_1, ec_dim_2, test_labels)

# %%
def train_test(data,labels):    
    from sklearn.model_selection import train_test_split 
    df_2 = pd.DataFrame(data)
    X = df_2
    y = labels
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0) 
    
    return(X_train, X_test, y_train, y_test)

def kNN_classifier(x_train, y_train, x_test, y_test):
    # training a KNN classifier 
    from sklearn.neighbors import KNeighborsClassifier 
    knn = KNeighborsClassifier(n_neighbors = 25).fit(x_train, y_train) 

    # accuracy on X_test 
    accuracy = knn.score(x_test, y_test) 

    # creating a confusion matrix 
    knn_predictions = knn.predict(x_test)  
    cm = confusion_matrix(y_test, knn_predictions)
    return cm, accuracy

def SVM_classifier(x_train, y_train, x_test, y_test):
    from sklearn.svm import SVC 
    svm_model_linear = SVC(kernel = 'linear', C = 1).fit(x_train, y_train) 
    svm_predictions = svm_model_linear.predict(x_test) 

    # model accuracy for X_test   
    accuracy = svm_model_linear.score(x_test, y_test) 

    # creating a confusion matrix 
    cm = confusion_matrix(y_test, svm_predictions) 
    return cm, accuracy

# %%
    
x_train_enc, x_test_enc, y_train_enc, y_test_enc = train_test(deep_encoded_imgs , y_test)

cm_kNN, accuracy_kNN = kNN_classifier(x_train_enc, y_train_enc, x_test_enc, y_test_enc)
cm_SVM, accuracy_SVM = SVM_classifier(x_train_enc, y_train_enc, x_test_enc, y_test_enc)

print(cm_kNN)
print(accuracy_kNN) 
print(cm_SVM)
print(accuracy_SVM)
# Out:
# C:\Users\kpvedula\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   from ipykernel import kernelapp as app
# C:\Users\kpvedula\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[123   2  19   2   9   1   8   5  40   3]
#  [ 29  34  25   4  30   4  50   4  65  18]
#  [ 49   2  90   5  43   5  32   2  10   4]
#  [ 28   4  40  31  43  24  58  11  11   3]
#  [ 22   3  84   4 105   2  31   5  11   0]
#  [ 18   2  44  29  45  44  43   5   8   4]
#  [ 10   2  50   8  57   8 107   5   6   2]
#  [ 25   2  33   6  59  15  29  66   7   9]
#  [ 48   4   4   4   7   4   7   5 168   5]
#  [ 24  11  12   4  23   5  25  10  63  82]]
# 0.34
# [[105  11  26  12   4   3   4   9  28  10]
#  [ 20 123  12  13   4   9  12  11  18  41]
#  [ 35  10  57  14  45  12  34  24   8   3]
#  [ 13  15  22  66  12  35  46  18   8  18]
#  [ 15   8  39  15 109  12  37  20   9   3]
#  [ 12  18  27  47  15  63  26  22   7   5]
#  [  4  14  35  24  33  14 112   7   5   7]
#  [ 19   9  27  21  32  10  16  99   2  16]
#  [ 48  15   8   8   4   7   2   6 134  24]
#  [ 18  51   3  13   7   3  12  14  16 122]]
# 0.396

# %%
# cm_kNN, accuracy_kNN = kNN_classifier(x_train, y_train, x_test, y_test)
# cm_SVM, accuracy_SVM = SVM_classifier(x_train, y_train, x_test, y_test)

# print(cm_kNN)
# print(accuracy_kNN) 
# print(cm_SVM)
# print(accuracy_SVM)

# %%
x_train_enc, x_test_enc, y_train_enc, y_test_enc = train_test(simple_encoded_imgs , y_test)

cm_kNN, accuracy_kNN = kNN_classifier(x_train_enc, y_train_enc, x_test_enc, y_test_enc)
cm_SVM, accuracy_SVM = SVM_classifier(x_train_enc, y_train_enc, x_test_enc, y_test_enc)

print(cm_kNN)
print(accuracy_kNN) 
print(cm_SVM)
print(accuracy_SVM)
# Out:
# C:\Users\kpvedula\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   from ipykernel import kernelapp as app
# C:\Users\kpvedula\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[122   1  21   3  14   1  11   6  32   1]
#  [ 23  48  24   4  27   2  55   3  54  23]
#  [ 45   1  93   6  43   4  39   1   8   2]
#  [ 23   5  47  26  48  18  68   7   7   4]
#  [ 16   0  72   5  99   3  54   7  10   1]
#  [ 22   1  50  25  36  32  59   5  10   2]
#  [  6   0  43   9  49   4 126  10   7   1]
#  [ 24   1  39  10  61   9  30  60  10   7]
#  [ 49   6   7   5  11   6   5   5 156   6]
#  [ 22  18  16   2  24   3  38  10  66  60]]
# 0.3288
# [[109  13  19   9   1   4   7   7  32  11]
#  [ 27 111  11  22   1   5  15  12  17  42]
#  [ 37  14  59  21  25  17  39  17  10   3]
#  [ 13  19  15  57  15  45  43  14  15  17]
#  [ 13   8  34  23  80  18  53  24   8   6]
#  [ 15  13  30  52  11  64  29  15   9   4]
#  [  3  22  20  30  32  18 113   6   3   8]
#  [ 16  16  23  21  30  15  19  94   5  12]
#  [ 51  21   7   5   1   6   1  10 129  25]
#  [ 20  49   5   9   3   4  17  11  21 120]]
# 0.3744
